# %% [markdown]
# # Simplest Case

# %%
from hyperopt import fmin, tpe, hp, STATUS_OK

# %%
def objective(x):
    return {'loss': x**2, 'status': STATUS_OK}

best = fmin(
    objective,
    space = hp.uniform('x', -10, 10),
    algo=tpe.suggest,
    max_evals=100
)

print(best)
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 185.01trial/s, best loss: 0.005057693200579573]
# {'x': np.float64(-0.07111746058865975)}

# %% [markdown]
# # Trials Object

# %%
from hyperopt import Trials
import time
import pickle

# %%
def objective(x):
    return {
        'loss': x**2,
        'status': STATUS_OK,
        'eval_time': time.time(),
        'other_stuff': {'type': None, 'value': [0, 1, 2]},
        'attachments':
            {'time_module': pickle.dumps(time.time)}
    }

trials = Trials()

best = fmin(
    objective,
    space=hp.uniform('x', -10, 10),
    algo=tpe.suggest,
    max_evals=100,
    trials=trials
)

print(best)
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 536.56trial/s, best loss: 1.1969930706484173e-05]
# {'x': np.float64(-0.0034597587642036798)}

# %%
trials.trials
# Out:
# [{'state': 2,
#   'tid': 0,
#   'spec': None,
#   'result': {'loss': 13.712212673418934,
#    'status': 'ok',
#    'eval_time': 1729230241.0525074,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 0,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [np.int64(0)]},
#    'vals': {'x': [np.float64(-3.703000496005764)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 52000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 52000)},
#  {'state': 2,
#   'tid': 1,
#   'spec': None,
#   'result': {'loss': 12.452842773822159,
#    'status': 'ok',
#    'eval_time': 1729230241.0535064,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 1,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [np.int64(1)]},
#    'vals': {'x': [np.float64(3.5288585652902213)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 53000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 53000)},
#  {'state': 2,
#   'tid': 2,
#   'spec': None,
#   'result': {'loss': 78.2613528656448,
#    'status': 'ok',
#    'eval_time': 1729230241.0535064,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 2,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [np.int64(2)]},
#    'vals': {'x': [np.float64(8.84654468510982)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 53000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 53000)},
#  {'state': 2,
#   'tid': 3,
#   'spec': None,
#   'result': {'loss': 88.68023263335517,
#    'status': 'ok',
#    'eval_time': 1729230241.0550146,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 3,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [np.int64(3)]},
#    'vals': {'x': [np.float64(9.41701824535533)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 53000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 55000)},
#  {'state': 2,
#   'tid': 4,
#   'spec': None,
#   'result': {'loss': 37.401688448560975,
#    'status': 'ok',
#    'eval_time': 1729230241.0550146,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 4,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [np.int64(4)]},
#    'vals': {'x': [np.float64(-6.1156919844414155)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 55000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 55000)},
#  {'state': 2,
#   'tid': 5,
#   'spec': None,
#   'result': {'loss': 47.92738459784967,
#    'status': 'ok',
#    'eval_time': 1729230241.0565372,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 5,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [np.int64(5)]},
#    'vals': {'x': [np.float64(6.922960681518397)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 56000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 56000)},
#  {'state': 2,
#   'tid': 6,
#   'spec': None,
#   'result': {'loss': 74.11184653398496,
#    'status': 'ok',
#    'eval_time': 1729230241.0575476,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 6,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [np.int64(6)]},
#    'vals': {'x': [np.float64(8.608823760188436)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 57000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 57000)},
#  {'state': 2,
#   'tid': 7,
#   'spec': None,
#   'result': {'loss': 31.007478469324578,
#    'status': 'ok',
#    'eval_time': 1729230241.0585494,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 7,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [np.int64(7)]},
#    'vals': {'x': [np.float64(-5.568435908702243)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 58000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 58000)},
#  {'state': 2,
#   'tid': 8,
#   'spec': None,
#   'result': {'loss': 6.184612297266336,
#    'status': 'ok',
#    'eval_time': 1729230241.0595474,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 8,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [np.int64(8)]},
#    'vals': {'x': [np.float64(-2.4868880749374984)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 59000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 59000)},
#  {'state': 2,
#   'tid': 9,
#   'spec': None,
#   'result': {'loss': 51.68661254516905,
#    'status': 'ok',
#    'eval_time': 1729230241.0595474,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 9,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [np.int64(9)]},
#    'vals': {'x': [np.float64(-7.189340202352998)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 59000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 59000)},
#  {'state': 2,
#   'tid': 10,
#   'spec': None,
#   'result': {'loss': 2.6589058338618408,
#    'status': 'ok',
#    'eval_time': 1729230241.0605452,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 10,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [np.int64(10)]},
#    'vals': {'x': [np.float64(1.6306151703764566)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 60000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 60000)},
#  {'state': 2,
#   'tid': 11,
#   'spec': None,
#   'result': {'loss': 53.76774571442771,
#    'status': 'ok',
#    'eval_time': 1729230241.0625463,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 11,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [np.int64(11)]},
#    'vals': {'x': [np.float64(7.3326492971113595)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 62000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 62000)},
#  {'state': 2,
#   'tid': 12,
#   'spec': None,
#   'result': {'loss': 3.958511483454956,
#    'status': 'ok',
#    'eval_time': 1729230241.0635486,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 12,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [np.int64(12)]},
#    'vals': {'x': [np.float64(-1.9896008352066392)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 63000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 63000)},
#  {'state': 2,
#   'tid': 13,
#   'spec': None,
#   'result': {'loss': 51.78237148227251,
#    'status': 'ok',
#    'eval_time': 1729230241.0635486,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 13,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [np.int64(13)]},
#    'vals': {'x': [np.float64(-7.195996906772022)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 63000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 63000)},
#  {'state': 2,
#   'tid': 14,
#   'spec': None,
#   'result': {'loss': 0.6120892716875113,
#    'status': 'ok',
#    'eval_time': 1729230241.065058,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 14,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [np.int64(14)]},
#    'vals': {'x': [np.float64(0.7823613434261123)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 65000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 65000)},
#  {'state': 2,
#   'tid': 15,
#   'spec': None,
#   'result': {'loss': 14.82260346916101,
#    'status': 'ok',
#    'eval_time': 1729230241.0660741,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 15,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [np.int64(15)]},
#    'vals': {'x': [np.float64(3.8500134375299275)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 66000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 66000)},
#  {'state': 2,
#   'tid': 16,
#   'spec': None,
#   'result': {'loss': 80.54171615597676,
#    'status': 'ok',
#    'eval_time': 1729230241.066586,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 16,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [np.int64(16)]},
#    'vals': {'x': [np.float64(-8.974503671845968)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 66000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 66000)},
#  {'state': 2,
#   'tid': 17,
#   'spec': None,
#   'result': {'loss': 8.882877397069148,
#    'status': 'ok',
#    'eval_time': 1729230241.0675972,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 17,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [np.int64(17)]},
#    'vals': {'x': [np.float64(2.9804156416629457)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 67000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 67000)},
#  {'state': 2,
#   'tid': 18,
#   'spec': None,
#   'result': {'loss': 1.052834415543154,
#    'status': 'ok',
#    'eval_time': 1729230241.0686004,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 18,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [np.int64(18)]},
#    'vals': {'x': [np.float64(1.0260771976528638)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 68000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 68000)},
#  {'state': 2,
#   'tid': 19,
#   'spec': None,
#   'result': {'loss': 24.77747958624523,
#    'status': 'ok',
#    'eval_time': 1729230241.069596,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 19,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [np.int64(19)]},
#    'vals': {'x': [np.float64(4.9776982216929575)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 69000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 69000)},
#  {'state': 2,
#   'tid': 20,
#   'spec': None,
#   'result': {'loss': 0.16929647576441767,
#    'status': 'ok',
#    'eval_time': 1729230241.0735996,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 20,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [20]},
#    'vals': {'x': [np.float64(0.41145652961694223)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 73000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 73000)},
#  {'state': 2,
#   'tid': 21,
#   'spec': None,
#   'result': {'loss': 0.1928288095074163,
#    'status': 'ok',
#    'eval_time': 1729230241.076644,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 21,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [21]},
#    'vals': {'x': [np.float64(-0.43912277270419064)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 76000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 76000)},
#  {'state': 2,
#   'tid': 22,
#   'spec': None,
#   'result': {'loss': 0.6718987740538706,
#    'status': 'ok',
#    'eval_time': 1729230241.0792246,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 22,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [22]},
#    'vals': {'x': [np.float64(-0.8196943174463701)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 79000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 79000)},
#  {'state': 2,
#   'tid': 23,
#   'spec': None,
#   'result': {'loss': 16.261394423169968,
#    'status': 'ok',
#    'eval_time': 1729230241.0802224,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 23,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [23]},
#    'vals': {'x': [np.float64(-4.0325419307392165)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 80000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 80000)},
#  {'state': 2,
#   'tid': 24,
#   'spec': None,
#   'result': {'loss': 0.6033252177434306,
#    'status': 'ok',
#    'eval_time': 1729230241.0822198,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 24,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [24]},
#    'vals': {'x': [np.float64(-0.7767401223983673)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 82000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 82000)},
#  {'state': 2,
#   'tid': 25,
#   'spec': None,
#   'result': {'loss': 27.138240274450627,
#    'status': 'ok',
#    'eval_time': 1729230241.0832198,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 25,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [25]},
#    'vals': {'x': [np.float64(5.209437615947678)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 83000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 83000)},
#  {'state': 2,
#   'tid': 26,
#   'spec': None,
#   'result': {'loss': 4.752323236355777,
#    'status': 'ok',
#    'eval_time': 1729230241.0857348,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 26,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [26]},
#    'vals': {'x': [np.float64(2.1799823935884843)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 85000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 85000)},
#  {'state': 2,
#   'tid': 27,
#   'spec': None,
#   'result': {'loss': 0.012287590490899817,
#    'status': 'ok',
#    'eval_time': 1729230241.088753,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 27,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [27]},
#    'vals': {'x': [np.float64(-0.11084940455816539)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 88000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 88000)},
#  {'state': 2,
#   'tid': 28,
#   'spec': None,
#   'result': {'loss': 13.606056595099718,
#    'status': 'ok',
#    'eval_time': 1729230241.0907516,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 28,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [28]},
#    'vals': {'x': [np.float64(-3.688638853981197)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 90000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 90000)},
#  {'state': 2,
#   'tid': 29,
#   'spec': None,
#   'result': {'loss': 4.83959237126871,
#    'status': 'ok',
#    'eval_time': 1729230241.0927553,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 29,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [29]},
#    'vals': {'x': [np.float64(-2.199907355155828)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 92000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 92000)},
#  {'state': 2,
#   'tid': 30,
#   'spec': None,
#   'result': {'loss': 14.436267769616101,
#    'status': 'ok',
#    'eval_time': 1729230241.0937493,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 30,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [30]},
#    'vals': {'x': [np.float64(-3.799508885318746)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 93000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 93000)},
#  {'state': 2,
#   'tid': 31,
#   'spec': None,
#   'result': {'loss': 29.36374301709497,
#    'status': 'ok',
#    'eval_time': 1729230241.0957744,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 31,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [31]},
#    'vals': {'x': [np.float64(5.418832255855035)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 95000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 95000)},
#  {'state': 2,
#   'tid': 32,
#   'spec': None,
#   'result': {'loss': 0.14974350546023807,
#    'status': 'ok',
#    'eval_time': 1729230241.0977821,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 32,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [32]},
#    'vals': {'x': [np.float64(0.3869670599162648)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 97000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 97000)},
#  {'state': 2,
#   'tid': 33,
#   'spec': None,
#   'result': {'loss': 9.522664868426753,
#    'status': 'ok',
#    'eval_time': 1729230241.0987813,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 33,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [33]},
#    'vals': {'x': [np.float64(3.085881538300969)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 98000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 98000)},
#  {'state': 2,
#   'tid': 34,
#   'spec': None,
#   'result': {'loss': 96.46714255539541,
#    'status': 'ok',
#    'eval_time': 1729230241.1007836,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 34,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [34]},
#    'vals': {'x': [np.float64(-9.821768809913793)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 100000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 100000)},
#  {'state': 2,
#   'tid': 35,
#   'spec': None,
#   'result': {'loss': 29.065220005572044,
#    'status': 'ok',
#    'eval_time': 1729230241.103786,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 35,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [35]},
#    'vals': {'x': [np.float64(-5.391216931785628)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 103000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 103000)},
#  {'state': 2,
#   'tid': 36,
#   'spec': None,
#   'result': {'loss': 2.7187159531898755,
#    'status': 'ok',
#    'eval_time': 1729230241.1068294,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 36,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [36]},
#    'vals': {'x': [np.float64(-1.6488529204237337)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 106000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 106000)},
#  {'state': 2,
#   'tid': 37,
#   'spec': None,
#   'result': {'loss': 4.643550408780898,
#    'status': 'ok',
#    'eval_time': 1729230241.1088252,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 37,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [37]},
#    'vals': {'x': [np.float64(2.1548898832146617)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 108000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 108000)},
#  {'state': 2,
#   'tid': 38,
#   'spec': None,
#   'result': {'loss': 57.21681958416952,
#    'status': 'ok',
#    'eval_time': 1729230241.1108294,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 38,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [38]},
#    'vals': {'x': [np.float64(7.564180033828486)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 110000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 110000)},
#  {'state': 2,
#   'tid': 39,
#   'spec': None,
#   'result': {'loss': 18.534462961931798,
#    'status': 'ok',
#    'eval_time': 1729230241.1138296,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 39,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [39]},
#    'vals': {'x': [np.float64(4.305167007437899)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 113000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 113000)},
#  {'state': 2,
#   'tid': 40,
#   'spec': None,
#   'result': {'loss': 10.158903008888997,
#    'status': 'ok',
#    'eval_time': 1729230241.1178918,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 40,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [40]},
#    'vals': {'x': [np.float64(-3.1873034070965063)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 117000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 117000)},
#  {'state': 2,
#   'tid': 41,
#   'spec': None,
#   'result': {'loss': 41.11254792457075,
#    'status': 'ok',
#    'eval_time': 1729230241.120892,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 41,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [41]},
#    'vals': {'x': [np.float64(6.411906730807206)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 119000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 120000)},
#  {'state': 2,
#   'tid': 42,
#   'spec': None,
#   'result': {'loss': 45.56343037007948,
#    'status': 'ok',
#    'eval_time': 1729230241.121891,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 42,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [42]},
#    'vals': {'x': [np.float64(-6.750068915950376)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 121000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 121000)},
#  {'state': 2,
#   'tid': 43,
#   'spec': None,
#   'result': {'loss': 97.023959608031,
#    'status': 'ok',
#    'eval_time': 1729230241.123891,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 43,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [43]},
#    'vals': {'x': [np.float64(9.850074091499566)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 123000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 123000)},
#  {'state': 2,
#   'tid': 44,
#   'spec': None,
#   'result': {'loss': 25.784392162440902,
#    'status': 'ok',
#    'eval_time': 1729230241.1269236,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 44,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [44]},
#    'vals': {'x': [np.float64(-5.077833412238029)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 126000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 126000)},
#  {'state': 2,
#   'tid': 45,
#   'spec': None,
#   'result': {'loss': 68.14333737402467,
#    'status': 'ok',
#    'eval_time': 1729230241.1299355,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 45,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [45]},
#    'vals': {'x': [np.float64(-8.254897780955538)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 128000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 129000)},
#  {'state': 2,
#   'tid': 46,
#   'spec': None,
#   'result': {'loss': 74.29285493747288,
#    'status': 'ok',
#    'eval_time': 1729230241.1309292,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 46,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [46]},
#    'vals': {'x': [np.float64(8.619330306785608)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 130000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 130000)},
#  {'state': 2,
#   'tid': 47,
#   'spec': None,
#   'result': {'loss': 1.9929985829774848,
#    'status': 'ok',
#    'eval_time': 1729230241.1329286,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 47,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [47]},
#    'vals': {'x': [np.float64(1.411736017454214)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 132000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 132000)},
#  {'state': 2,
#   'tid': 48,
#   'spec': None,
#   'result': {'loss': 1.9984476631468289,
#    'status': 'ok',
#    'eval_time': 1729230241.1339285,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 48,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [48]},
#    'vals': {'x': [np.float64(-1.4136646218770663)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 133000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 134000)},
#  {'state': 2,
#   'tid': 49,
#   'spec': None,
#   'result': {'loss': 0.2080424874123079,
#    'status': 'ok',
#    'eval_time': 1729230241.1360846,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 49,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [49]},
#    'vals': {'x': [np.float64(0.4561167475683259)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 136000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 136000)},
#  {'state': 2,
#   'tid': 50,
#   'spec': None,
#   'result': {'loss': 7.429220605916498,
#    'status': 'ok',
#    'eval_time': 1729230241.1372068,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 50,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [50]},
#    'vals': {'x': [np.float64(-2.7256596643595286)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 137000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 137000)},
#  {'state': 2,
#   'tid': 51,
#   'spec': None,
#   'result': {'loss': 19.362813478191157,
#    'status': 'ok',
#    'eval_time': 1729230241.1392138,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 51,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [51]},
#    'vals': {'x': [np.float64(-4.400319701816126)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 139000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 139000)},
#  {'state': 2,
#   'tid': 52,
#   'spec': None,
#   'result': {'loss': 38.91623923370914,
#    'status': 'ok',
#    'eval_time': 1729230241.1402133,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 52,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [52]},
#    'vals': {'x': [np.float64(6.238288165331026)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 140000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 140000)},
#  {'state': 2,
#   'tid': 53,
#   'spec': None,
#   'result': {'loss': 1.1969930706484173e-05,
#    'status': 'ok',
#    'eval_time': 1729230241.1422203,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 53,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [53]},
#    'vals': {'x': [np.float64(-0.0034597587642036798)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 142000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 142000)},
#  {'state': 2,
#   'tid': 54,
#   'spec': None,
#   'result': {'loss': 5.6347212010579515,
#    'status': 'ok',
#    'eval_time': 1729230241.1442134,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 54,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [54]},
#    'vals': {'x': [np.float64(2.3737567695654818)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 144000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 144000)},
#  {'state': 2,
#   'tid': 55,
#   'spec': None,
#   'result': {'loss': 15.890795834017803,
#    'status': 'ok',
#    'eval_time': 1729230241.145717,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 55,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [55]},
#    'vals': {'x': [np.float64(3.9863261073346474)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 145000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 145000)},
#  {'state': 2,
#   'tid': 56,
#   'spec': None,
#   'result': {'loss': 0.022292195520220708,
#    'status': 'ok',
#    'eval_time': 1729230241.1472323,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 56,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [56]},
#    'vals': {'x': [np.float64(-0.14930571161285394)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 147000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 147000)},
#  {'state': 2,
#   'tid': 57,
#   'spec': None,
#   'result': {'loss': 38.65587326761402,
#    'status': 'ok',
#    'eval_time': 1729230241.1482377,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 57,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [57]},
#    'vals': {'x': [np.float64(-6.217384761104465)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 148000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 148000)},
#  {'state': 2,
#   'tid': 58,
#   'spec': None,
#   'result': {'loss': 9.886516008128764,
#    'status': 'ok',
#    'eval_time': 1729230241.1502373,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 58,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [58]},
#    'vals': {'x': [np.float64(3.144283067430279)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 150000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 150000)},
#  {'state': 2,
#   'tid': 59,
#   'spec': None,
#   'result': {'loss': 1.194026739938534,
#    'status': 'ok',
#    'eval_time': 1729230241.1522374,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 59,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [59]},
#    'vals': {'x': [np.float64(-1.092715305987124)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 152000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 152000)},
#  {'state': 2,
#   'tid': 60,
#   'spec': None,
#   'result': {'loss': 61.52445734706482,
#    'status': 'ok',
#    'eval_time': 1729230241.154239,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 60,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [60]},
#    'vals': {'x': [np.float64(-7.843752759174961)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 154000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 154000)},
#  {'state': 2,
#   'tid': 61,
#   'spec': None,
#   'result': {'loss': 2.610152378502443,
#    'status': 'ok',
#    'eval_time': 1729230241.1567557,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 61,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [61]},
#    'vals': {'x': [np.float64(1.6155966014146115)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 156000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 157000)},
#  {'state': 2,
#   'tid': 62,
#   'spec': None,
#   'result': {'loss': 22.94869041542138,
#    'status': 'ok',
#    'eval_time': 1729230241.1577628,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 62,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [62]},
#    'vals': {'x': [np.float64(-4.790479142572419)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 157000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 158000)},
#  {'state': 2,
#   'tid': 63,
#   'spec': None,
#   'result': {'loss': 5.376281957349895,
#    'status': 'ok',
#    'eval_time': 1729230241.159762,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 63,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [63]},
#    'vals': {'x': [np.float64(-2.3186810814232075)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 159000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 159000)},
#  {'state': 2,
#   'tid': 64,
#   'spec': None,
#   'result': {'loss': 20.569659446377397,
#    'status': 'ok',
#    'eval_time': 1729230241.161763,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 64,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [64]},
#    'vals': {'x': [np.float64(4.535378644212344)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 161000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 161000)},
#  {'state': 2,
#   'tid': 65,
#   'spec': None,
#   'result': {'loss': 0.24565597927309135,
#    'status': 'ok',
#    'eval_time': 1729230241.1627622,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 65,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [65]},
#    'vals': {'x': [np.float64(-0.49563694300676514)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 162000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 163000)},
#  {'state': 2,
#   'tid': 66,
#   'spec': None,
#   'result': {'loss': 0.05765944046313243,
#    'status': 'ok',
#    'eval_time': 1729230241.1652691,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 66,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [66]},
#    'vals': {'x': [np.float64(-0.2401238023668883)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 165000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 165000)},
#  {'state': 2,
#   'tid': 67,
#   'spec': None,
#   'result': {'loss': 9.926275988075298,
#    'status': 'ok',
#    'eval_time': 1729230241.1678011,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 67,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [67]},
#    'vals': {'x': [np.float64(-3.1505993061757787)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 167000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 167000)},
#  {'state': 2,
#   'tid': 68,
#   'spec': None,
#   'result': {'loss': 0.963876493501056,
#    'status': 'ok',
#    'eval_time': 1729230241.1717966,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 68,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [68]},
#    'vals': {'x': [np.float64(0.9817721189263097)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 171000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 171000)},
#  {'state': 2,
#   'tid': 69,
#   'spec': None,
#   'result': {'loss': 0.0035158671873694587,
#    'status': 'ok',
#    'eval_time': 1729230241.1753097,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 69,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [69]},
#    'vals': {'x': [np.float64(0.059294748396206715)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 175000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 175000)},
#  {'state': 2,
#   'tid': 70,
#   'spec': None,
#   'result': {'loss': 2.860405589008574,
#    'status': 'ok',
#    'eval_time': 1729230241.1771786,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 70,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [70]},
#    'vals': {'x': [np.float64(-1.691273363181888)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 177000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 177000)},
#  {'state': 2,
#   'tid': 71,
#   'spec': None,
#   'result': {'loss': 5.422781504471777,
#    'status': 'ok',
#    'eval_time': 1729230241.1791918,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 71,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [71]},
#    'vals': {'x': [np.float64(2.328686647978164)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 179000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 179000)},
#  {'state': 2,
#   'tid': 72,
#   'spec': None,
#   'result': {'loss': 0.0819337574647208,
#    'status': 'ok',
#    'eval_time': 1729230241.1811926,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 72,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [72]},
#    'vals': {'x': [np.float64(0.28624073341284045)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 181000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 181000)},
#  {'state': 2,
#   'tid': 73,
#   'spec': None,
#   'result': {'loss': 11.76216211090498,
#    'status': 'ok',
#    'eval_time': 1729230241.184187,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 73,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [73]},
#    'vals': {'x': [np.float64(3.429600867579926)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 184000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 184000)},
#  {'state': 2,
#   'tid': 74,
#   'spec': None,
#   'result': {'loss': 1.388588610815438,
#    'status': 'ok',
#    'eval_time': 1729230241.1867113,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 74,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [74]},
#    'vals': {'x': [np.float64(1.1783838978938221)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 186000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 186000)},
#  {'state': 2,
#   'tid': 75,
#   'spec': None,
#   'result': {'loss': 32.73581071709003,
#    'status': 'ok',
#    'eval_time': 1729230241.1897051,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 75,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [75]},
#    'vals': {'x': [np.float64(5.721521713415936)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 189000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 189000)},
#  {'state': 2,
#   'tid': 76,
#   'spec': None,
#   'result': {'loss': 6.747456855224154,
#    'status': 'ok',
#    'eval_time': 1729230241.1917062,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 76,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [76]},
#    'vals': {'x': [np.float64(2.5975867368047894)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 191000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 191000)},
#  {'state': 2,
#   'tid': 77,
#   'spec': None,
#   'result': {'loss': 10.215795008436762,
#    'status': 'ok',
#    'eval_time': 1729230241.1927059,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 77,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [77]},
#    'vals': {'x': [np.float64(-3.196215732461869)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 192000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 192000)},
#  {'state': 2,
#   'tid': 78,
#   'spec': None,
#   'result': {'loss': 65.77906493656836,
#    'status': 'ok',
#    'eval_time': 1729230241.1952195,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 78,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [78]},
#    'vals': {'x': [np.float64(8.110429392860057)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 193000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 195000)},
#  {'state': 2,
#   'tid': 79,
#   'spec': None,
#   'result': {'loss': 0.5315692988964074,
#    'status': 'ok',
#    'eval_time': 1729230241.19695,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 79,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [79]},
#    'vals': {'x': [np.float64(-0.7290879911892716)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 196000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 196000)},
#  {'state': 2,
#   'tid': 80,
#   'spec': None,
#   'result': {'loss': 3.825730161623086,
#    'status': 'ok',
#    'eval_time': 1729230241.1989563,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 80,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [80]},
#    'vals': {'x': [np.float64(-1.9559473821202569)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 198000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 198000)},
#  {'state': 2,
#   'tid': 81,
#   'spec': None,
#   'result': {'loss': 3.7486130779078426,
#    'status': 'ok',
#    'eval_time': 1729230241.199954,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 81,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [81]},
#    'vals': {'x': [np.float64(1.9361335382426086)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 199000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 199000)},
#  {'state': 2,
#   'tid': 82,
#   'spec': None,
#   'result': {'loss': 23.726806423331542,
#    'status': 'ok',
#    'eval_time': 1729230241.2019544,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 82,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [82]},
#    'vals': {'x': [np.float64(4.871016980398605)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 201000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 201000)},
#  {'state': 2,
#   'tid': 83,
#   'spec': None,
#   'result': {'loss': 0.40843628198615783,
#    'status': 'ok',
#    'eval_time': 1729230241.203956,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 83,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [83]},
#    'vals': {'x': [np.float64(0.6390901986309584)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 203000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 203000)},
#  {'state': 2,
#   'tid': 84,
#   'spec': None,
#   'result': {'loss': 1.1381116911054199,
#    'status': 'ok',
#    'eval_time': 1729230241.205459,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 84,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [84]},
#    'vals': {'x': [np.float64(-1.0668231770567322)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 205000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 205000)},
#  {'state': 2,
#   'tid': 85,
#   'spec': None,
#   'result': {'loss': 19.850170951159775,
#    'status': 'ok',
#    'eval_time': 1729230241.2069683,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 85,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [85]},
#    'vals': {'x': [np.float64(-4.4553530669476435)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 206000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 206000)},
#  {'state': 2,
#   'tid': 86,
#   'spec': None,
#   'result': {'loss': 32.25262761567292,
#    'status': 'ok',
#    'eval_time': 1729230241.2089686,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 86,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [86]},
#    'vals': {'x': [np.float64(-5.679139689748168)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 208000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 208000)},
#  {'state': 2,
#   'tid': 87,
#   'spec': None,
#   'result': {'loss': 13.454645955918162,
#    'status': 'ok',
#    'eval_time': 1729230241.2109728,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 87,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [87]},
#    'vals': {'x': [np.float64(3.6680575180765858)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 209000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 210000)},
#  {'state': 2,
#   'tid': 88,
#   'spec': None,
#   'result': {'loss': 6.664586037197523,
#    'status': 'ok',
#    'eval_time': 1729230241.212969,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 88,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [88]},
#    'vals': {'x': [np.float64(-2.581585953865864)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 212000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 212000)},
#  {'state': 2,
#   'tid': 89,
#   'spec': None,
#   'result': {'loss': 8.222879004992016,
#    'status': 'ok',
#    'eval_time': 1729230241.2149692,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 89,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [89]},
#    'vals': {'x': [np.float64(2.8675562775631827)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 213000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 214000)},
#  {'state': 2,
#   'tid': 90,
#   'spec': None,
#   'result': {'loss': 0.00178384014836884,
#    'status': 'ok',
#    'eval_time': 1729230241.216823,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 90,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [90]},
#    'vals': {'x': [np.float64(0.042235531822966785)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 215000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 216000)},
#  {'state': 2,
#   'tid': 91,
#   'spec': None,
#   'result': {'loss': 12.57395680784508,
#    'status': 'ok',
#    'eval_time': 1729230241.219824,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 91,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [91]},
#    'vals': {'x': [np.float64(-3.545977553206602)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 219000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 219000)},
#  {'state': 2,
#   'tid': 92,
#   'spec': None,
#   'result': {'loss': 1.6181974744380656,
#    'status': 'ok',
#    'eval_time': 1729230241.2238288,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 92,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [92]},
#    'vals': {'x': [np.float64(-1.2720839101403907)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 223000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 223000)},
#  {'state': 2,
#   'tid': 93,
#   'spec': None,
#   'result': {'loss': 95.42553144716757,
#    'status': 'ok',
#    'eval_time': 1729230241.2253404,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 93,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [93]},
#    'vals': {'x': [np.float64(-9.768599257169248)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 225000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 225000)},
#  {'state': 2,
#   'tid': 94,
#   'spec': None,
#   'result': {'loss': 86.90475787585801,
#    'status': 'ok',
#    'eval_time': 1729230241.2268634,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 94,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [94]},
#    'vals': {'x': [np.float64(9.322272141267815)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 226000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 226000)},
#  {'state': 2,
#   'tid': 95,
#   'spec': None,
#   'result': {'loss': 47.48275907795631,
#    'status': 'ok',
#    'eval_time': 1729230241.2298691,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 95,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [95]},
#    'vals': {'x': [np.float64(6.89077347457862)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 229000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 229000)},
#  {'state': 2,
#   'tid': 96,
#   'spec': None,
#   'result': {'loss': 3.768215183667795,
#    'status': 'ok',
#    'eval_time': 1729230241.2318695,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 96,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [96]},
#    'vals': {'x': [np.float64(1.941189115894635)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 230000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 231000)},
#  {'state': 2,
#   'tid': 97,
#   'spec': None,
#   'result': {'loss': 1.9271952988341,
#    'status': 'ok',
#    'eval_time': 1729230241.2328687,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 97,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [97]},
#    'vals': {'x': [np.float64(1.3882345979099138)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 232000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 232000)},
#  {'state': 2,
#   'tid': 98,
#   'spec': None,
#   'result': {'loss': 0.038949074664650654,
#    'status': 'ok',
#    'eval_time': 1729230241.2353716,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 98,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [98]},
#    'vals': {'x': [np.float64(0.19735519923389566)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 235000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 235000)},
#  {'state': 2,
#   'tid': 99,
#   'spec': None,
#   'result': {'loss': 16.246793987101917,
#    'status': 'ok',
#    'eval_time': 1729230241.2371433,
#    'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#   'misc': {'tid': 99,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'x': [99]},
#    'vals': {'x': [np.float64(-4.030731197574693)]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 237000),
#   'refresh_time': datetime.datetime(2024, 10, 18, 5, 44, 1, 237000)}]

# %%
trials.results
# Out:
# [{'loss': 13.712212673418934,
#   'status': 'ok',
#   'eval_time': 1729230241.0525074,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 12.452842773822159,
#   'status': 'ok',
#   'eval_time': 1729230241.0535064,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 78.2613528656448,
#   'status': 'ok',
#   'eval_time': 1729230241.0535064,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 88.68023263335517,
#   'status': 'ok',
#   'eval_time': 1729230241.0550146,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 37.401688448560975,
#   'status': 'ok',
#   'eval_time': 1729230241.0550146,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 47.92738459784967,
#   'status': 'ok',
#   'eval_time': 1729230241.0565372,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 74.11184653398496,
#   'status': 'ok',
#   'eval_time': 1729230241.0575476,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 31.007478469324578,
#   'status': 'ok',
#   'eval_time': 1729230241.0585494,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 6.184612297266336,
#   'status': 'ok',
#   'eval_time': 1729230241.0595474,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 51.68661254516905,
#   'status': 'ok',
#   'eval_time': 1729230241.0595474,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 2.6589058338618408,
#   'status': 'ok',
#   'eval_time': 1729230241.0605452,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 53.76774571442771,
#   'status': 'ok',
#   'eval_time': 1729230241.0625463,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 3.958511483454956,
#   'status': 'ok',
#   'eval_time': 1729230241.0635486,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 51.78237148227251,
#   'status': 'ok',
#   'eval_time': 1729230241.0635486,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 0.6120892716875113,
#   'status': 'ok',
#   'eval_time': 1729230241.065058,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 14.82260346916101,
#   'status': 'ok',
#   'eval_time': 1729230241.0660741,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 80.54171615597676,
#   'status': 'ok',
#   'eval_time': 1729230241.066586,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 8.882877397069148,
#   'status': 'ok',
#   'eval_time': 1729230241.0675972,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 1.052834415543154,
#   'status': 'ok',
#   'eval_time': 1729230241.0686004,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 24.77747958624523,
#   'status': 'ok',
#   'eval_time': 1729230241.069596,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 0.16929647576441767,
#   'status': 'ok',
#   'eval_time': 1729230241.0735996,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 0.1928288095074163,
#   'status': 'ok',
#   'eval_time': 1729230241.076644,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 0.6718987740538706,
#   'status': 'ok',
#   'eval_time': 1729230241.0792246,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 16.261394423169968,
#   'status': 'ok',
#   'eval_time': 1729230241.0802224,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 0.6033252177434306,
#   'status': 'ok',
#   'eval_time': 1729230241.0822198,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 27.138240274450627,
#   'status': 'ok',
#   'eval_time': 1729230241.0832198,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 4.752323236355777,
#   'status': 'ok',
#   'eval_time': 1729230241.0857348,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 0.012287590490899817,
#   'status': 'ok',
#   'eval_time': 1729230241.088753,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 13.606056595099718,
#   'status': 'ok',
#   'eval_time': 1729230241.0907516,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 4.83959237126871,
#   'status': 'ok',
#   'eval_time': 1729230241.0927553,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 14.436267769616101,
#   'status': 'ok',
#   'eval_time': 1729230241.0937493,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 29.36374301709497,
#   'status': 'ok',
#   'eval_time': 1729230241.0957744,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 0.14974350546023807,
#   'status': 'ok',
#   'eval_time': 1729230241.0977821,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 9.522664868426753,
#   'status': 'ok',
#   'eval_time': 1729230241.0987813,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 96.46714255539541,
#   'status': 'ok',
#   'eval_time': 1729230241.1007836,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 29.065220005572044,
#   'status': 'ok',
#   'eval_time': 1729230241.103786,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 2.7187159531898755,
#   'status': 'ok',
#   'eval_time': 1729230241.1068294,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 4.643550408780898,
#   'status': 'ok',
#   'eval_time': 1729230241.1088252,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 57.21681958416952,
#   'status': 'ok',
#   'eval_time': 1729230241.1108294,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 18.534462961931798,
#   'status': 'ok',
#   'eval_time': 1729230241.1138296,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 10.158903008888997,
#   'status': 'ok',
#   'eval_time': 1729230241.1178918,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 41.11254792457075,
#   'status': 'ok',
#   'eval_time': 1729230241.120892,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 45.56343037007948,
#   'status': 'ok',
#   'eval_time': 1729230241.121891,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 97.023959608031,
#   'status': 'ok',
#   'eval_time': 1729230241.123891,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 25.784392162440902,
#   'status': 'ok',
#   'eval_time': 1729230241.1269236,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 68.14333737402467,
#   'status': 'ok',
#   'eval_time': 1729230241.1299355,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 74.29285493747288,
#   'status': 'ok',
#   'eval_time': 1729230241.1309292,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 1.9929985829774848,
#   'status': 'ok',
#   'eval_time': 1729230241.1329286,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 1.9984476631468289,
#   'status': 'ok',
#   'eval_time': 1729230241.1339285,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 0.2080424874123079,
#   'status': 'ok',
#   'eval_time': 1729230241.1360846,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 7.429220605916498,
#   'status': 'ok',
#   'eval_time': 1729230241.1372068,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 19.362813478191157,
#   'status': 'ok',
#   'eval_time': 1729230241.1392138,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 38.91623923370914,
#   'status': 'ok',
#   'eval_time': 1729230241.1402133,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 1.1969930706484173e-05,
#   'status': 'ok',
#   'eval_time': 1729230241.1422203,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 5.6347212010579515,
#   'status': 'ok',
#   'eval_time': 1729230241.1442134,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 15.890795834017803,
#   'status': 'ok',
#   'eval_time': 1729230241.145717,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 0.022292195520220708,
#   'status': 'ok',
#   'eval_time': 1729230241.1472323,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 38.65587326761402,
#   'status': 'ok',
#   'eval_time': 1729230241.1482377,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 9.886516008128764,
#   'status': 'ok',
#   'eval_time': 1729230241.1502373,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 1.194026739938534,
#   'status': 'ok',
#   'eval_time': 1729230241.1522374,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 61.52445734706482,
#   'status': 'ok',
#   'eval_time': 1729230241.154239,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 2.610152378502443,
#   'status': 'ok',
#   'eval_time': 1729230241.1567557,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 22.94869041542138,
#   'status': 'ok',
#   'eval_time': 1729230241.1577628,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 5.376281957349895,
#   'status': 'ok',
#   'eval_time': 1729230241.159762,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 20.569659446377397,
#   'status': 'ok',
#   'eval_time': 1729230241.161763,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 0.24565597927309135,
#   'status': 'ok',
#   'eval_time': 1729230241.1627622,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 0.05765944046313243,
#   'status': 'ok',
#   'eval_time': 1729230241.1652691,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 9.926275988075298,
#   'status': 'ok',
#   'eval_time': 1729230241.1678011,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 0.963876493501056,
#   'status': 'ok',
#   'eval_time': 1729230241.1717966,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 0.0035158671873694587,
#   'status': 'ok',
#   'eval_time': 1729230241.1753097,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 2.860405589008574,
#   'status': 'ok',
#   'eval_time': 1729230241.1771786,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 5.422781504471777,
#   'status': 'ok',
#   'eval_time': 1729230241.1791918,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 0.0819337574647208,
#   'status': 'ok',
#   'eval_time': 1729230241.1811926,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 11.76216211090498,
#   'status': 'ok',
#   'eval_time': 1729230241.184187,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 1.388588610815438,
#   'status': 'ok',
#   'eval_time': 1729230241.1867113,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 32.73581071709003,
#   'status': 'ok',
#   'eval_time': 1729230241.1897051,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 6.747456855224154,
#   'status': 'ok',
#   'eval_time': 1729230241.1917062,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 10.215795008436762,
#   'status': 'ok',
#   'eval_time': 1729230241.1927059,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 65.77906493656836,
#   'status': 'ok',
#   'eval_time': 1729230241.1952195,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 0.5315692988964074,
#   'status': 'ok',
#   'eval_time': 1729230241.19695,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 3.825730161623086,
#   'status': 'ok',
#   'eval_time': 1729230241.1989563,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 3.7486130779078426,
#   'status': 'ok',
#   'eval_time': 1729230241.199954,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 23.726806423331542,
#   'status': 'ok',
#   'eval_time': 1729230241.2019544,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 0.40843628198615783,
#   'status': 'ok',
#   'eval_time': 1729230241.203956,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 1.1381116911054199,
#   'status': 'ok',
#   'eval_time': 1729230241.205459,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 19.850170951159775,
#   'status': 'ok',
#   'eval_time': 1729230241.2069683,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 32.25262761567292,
#   'status': 'ok',
#   'eval_time': 1729230241.2089686,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 13.454645955918162,
#   'status': 'ok',
#   'eval_time': 1729230241.2109728,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 6.664586037197523,
#   'status': 'ok',
#   'eval_time': 1729230241.212969,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 8.222879004992016,
#   'status': 'ok',
#   'eval_time': 1729230241.2149692,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 0.00178384014836884,
#   'status': 'ok',
#   'eval_time': 1729230241.216823,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 12.57395680784508,
#   'status': 'ok',
#   'eval_time': 1729230241.219824,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 1.6181974744380656,
#   'status': 'ok',
#   'eval_time': 1729230241.2238288,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 95.42553144716757,
#   'status': 'ok',
#   'eval_time': 1729230241.2253404,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 86.90475787585801,
#   'status': 'ok',
#   'eval_time': 1729230241.2268634,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 47.48275907795631,
#   'status': 'ok',
#   'eval_time': 1729230241.2298691,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 3.768215183667795,
#   'status': 'ok',
#   'eval_time': 1729230241.2318695,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 1.9271952988341,
#   'status': 'ok',
#   'eval_time': 1729230241.2328687,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 0.038949074664650654,
#   'status': 'ok',
#   'eval_time': 1729230241.2353716,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}},
#  {'loss': 16.246793987101917,
#   'status': 'ok',
#   'eval_time': 1729230241.2371433,
#   'other_stuff': {'type': None, 'value': [0, 1, 2]}}]

# %%
trials.losses()
# Out:
# [13.712212673418934,
#  12.452842773822159,
#  78.2613528656448,
#  88.68023263335517,
#  37.401688448560975,
#  47.92738459784967,
#  74.11184653398496,
#  31.007478469324578,
#  6.184612297266336,
#  51.68661254516905,
#  2.6589058338618408,
#  53.76774571442771,
#  3.958511483454956,
#  51.78237148227251,
#  0.6120892716875113,
#  14.82260346916101,
#  80.54171615597676,
#  8.882877397069148,
#  1.052834415543154,
#  24.77747958624523,
#  0.16929647576441767,
#  0.1928288095074163,
#  0.6718987740538706,
#  16.261394423169968,
#  0.6033252177434306,
#  27.138240274450627,
#  4.752323236355777,
#  0.012287590490899817,
#  13.606056595099718,
#  4.83959237126871,
#  14.436267769616101,
#  29.36374301709497,
#  0.14974350546023807,
#  9.522664868426753,
#  96.46714255539541,
#  29.065220005572044,
#  2.7187159531898755,
#  4.643550408780898,
#  57.21681958416952,
#  18.534462961931798,
#  10.158903008888997,
#  41.11254792457075,
#  45.56343037007948,
#  97.023959608031,
#  25.784392162440902,
#  68.14333737402467,
#  74.29285493747288,
#  1.9929985829774848,
#  1.9984476631468289,
#  0.2080424874123079,
#  7.429220605916498,
#  19.362813478191157,
#  38.91623923370914,
#  1.1969930706484173e-05,
#  5.6347212010579515,
#  15.890795834017803,
#  0.022292195520220708,
#  38.65587326761402,
#  9.886516008128764,
#  1.194026739938534,
#  61.52445734706482,
#  2.610152378502443,
#  22.94869041542138,
#  5.376281957349895,
#  20.569659446377397,
#  0.24565597927309135,
#  0.05765944046313243,
#  9.926275988075298,
#  0.963876493501056,
#  0.0035158671873694587,
#  2.860405589008574,
#  5.422781504471777,
#  0.0819337574647208,
#  11.76216211090498,
#  1.388588610815438,
#  32.73581071709003,
#  6.747456855224154,
#  10.215795008436762,
#  65.77906493656836,
#  0.5315692988964074,
#  3.825730161623086,
#  3.7486130779078426,
#  23.726806423331542,
#  0.40843628198615783,
#  1.1381116911054199,
#  19.850170951159775,
#  32.25262761567292,
#  13.454645955918162,
#  6.664586037197523,
#  8.222879004992016,
#  0.00178384014836884,
#  12.57395680784508,
#  1.6181974744380656,
#  95.42553144716757,
#  86.90475787585801,
#  47.48275907795631,
#  3.768215183667795,
#  1.9271952988341,
#  0.038949074664650654,
#  16.246793987101917]

# %%
trials.statuses()
# Out:
# ['ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok']

# %% [markdown]
# ### One way to save and subsequently load a trials object

# %%
def objective(x):
    return {
        'loss': x**2,
        'status': STATUS_OK,
        'eval_time': time.time(),
        'other_stuff': {'type': None, 'value': [0, 1, 2]},
        'attachments':
            {'time_module': pickle.dumps(time.time)}
    }

# Initialize an empty trials database
trials = Trials()

# Perform 100 evaluations on the search space
best = fmin(objective,
            space=hp.uniform('x', -10, 10),
            algo=tpe.suggest,
            trials=trials,
            max_evals=100)


# The trials database now contains 100 entries, it can be saved/reloaded with pickle or another method
pickle.dump(trials, open("my_trials.pkl", "wb"))
trials_loaded = pickle.load(open("my_trials.pkl", "rb"))
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 536.17trial/s, best loss: 0.0006722093207300791]

# %%
print(best)
# Out:
# {'x': np.float64(-0.025926999840515275)}

# %%
best = fmin(objective,
    space=hp.uniform('x', -10, 10),
    algo=tpe.suggest,
    trials=trials_loaded,
    max_evals=200)

print(best)
# Out:
# 100%|██████████| 200/200 [00:00<00:00, 460.70trial/s, best loss: 0.00020264508655756328]
# {'x': np.float64(-0.01423534637996432)}

# %%
# Retrieve a trial attachment
# Retrieve the 'time_module' attachement of the 5th trial

msg = trials.trial_attachments(trials_loaded.trials[5])['time_module']
time_module_loaded = pickle.loads(msg)

# %%
print(type(time_module_loaded), time_module_loaded)
# Out:
# <class 'builtin_function_or_method'> <built-in function time>

# %%
time_module_loaded()
# Out:
# 1729231399.9277823

# %% [markdown]
# # Defining a Search Space

# %%
space = hp.choice('a',
                  [
                      ('case 1', 1+hp.lognormal('c1', 0, 1)),
                      ('case 2', hp.uniform('c2', -10, 10))
                  ])
space

# %%
import hyperopt.pyll.stochastic

print(hyperopt.pyll.stochastic.sample(space))
# Out:
# ('case 1', 3.566167905299063)

# %% [markdown]
# ### Search Space Example: scikit-learn

# %%
space = hp.choice('classifier_type',[
    {
        'type': 'naive_bayes'
     },
    {
        'type': 'svm',
        'C': hp.lognormal('svm_C', 0, 1),
        'kernel': hp.choice('svm_kernel', [
            {'ktype': 'linear'},
            {'ktype': 'RBF', 'width': hp.lognormal('svm_rbf_width', 0, 1)},
            ]),
    },
    {
        'type': 'dtree',
        'criterion': hp.choice('dtree_criterion', ['gini', 'entropy']),
        'max_depth': hp.choice('dtree_max_depth', [None, hp.qlognormal('dtree_max_depth_int', 3, 1, 1)]),
        'min_samples_split': hp.qlognormal('dtree_min_samples_split', 2, 1, 1),
    },
])

# %% [markdown]
# ### Adding Non-Stochastic Expressions with pyll

# %%
import hyperopt.pyll
from hyperopt.pyll import scope


@scope.define
def foo(a, b=0):
     print('runing foo', a, b)
     return a + b / 2

# -- this will print 0, foo is called as usual.
print(foo(0))
# Out:
# runing foo 0 0
# 0.0

# %%
# In describing search spaces you can use `foo` as you
# would in normal Python. These two calls will not actually call foo,
# they just record that foo should be called to evaluate the graph.

space1 = scope.foo(hp.uniform('a', 0, 10))
space2 = scope.foo(hp.uniform('a', 0, 10), hp.normal('b', 0, 1))

# %%
# -- this will print an pyll.Apply node
print(space1)
# Out:
# 0 foo
# 1   float
# 2     hyperopt_param
# 3       Literal{a}
# 4       uniform
# 5         Literal{0}
# 6         Literal{10}

# %%
# -- this will print an pyll.Apply node
print(space2)
# Out:
# 0 foo
# 1   float
# 2     hyperopt_param
# 3       Literal{a}
# 4       uniform
# 5         Literal{0}
# 6         Literal{10}
# 7   float
# 8     hyperopt_param
# 9       Literal{b}
# 10       normal
# 11         Literal{0}
# 12         Literal{1}

# %%
# -- this will draw a sample by running foo()
print(hyperopt.pyll.stochastic.sample(space1))
# Out:
# runing foo 0.8086980347602923 0
# 0.8086980347602923

# %%
# -- this will draw a sample by running foo()
print(hyperopt.pyll.stochastic.sample(space2))
# Out:
# runing foo 0.18196973271275452 -0.09751534405128713
# 0.13321206068711094
